# %% [markdown]
# <a href="https://colab.research.google.com/github/rakshitakanwar/day1.ipynb/blob/main/Day1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Rakshita")
# Out:
# Rakshita

# %%
#variable
num="Rakshita"
print(num)
print(id(num))
print(type(num))

num1="Arya-mains"
print(num1)
print(id(num1))
# Out:
# Rakshita
# 133084653655344
# <class 'str'>
# Arya-mains
# 133084653649968

# %%
user= int(input("enter a number:"))
print(user)
print(id(user))
print(type(user))
# Out:
# enter a number:67
# 67
# 11647464
# <class 'int'>

# %%
#boolean
user_id= True
print(user_id)
print(id(user_id))
print(type(user_id))
# Out:
# True
# 10549600
# <class 'bool'>

# %%
#float
user=15.9
print(user)
print(id(user))
print(type(user))
# Out:
# 15.9
# 134892273431120
# <class 'float'>
